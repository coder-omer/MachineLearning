# %% [markdown]
# # Hierarchical Clustering

# %% [markdown]
# This data set contains statistics, in arrests per 100,000 residents for assault, murder, and rape in each of the 50 US states in 1973. Also given is the percent of the population living in urban areas.
#
# A data frame with 50 observations on 4 variables.
#
# - Murder numeric Murder arrests (per 100,000) (K)
# - Assault numeric Assault arrests (per 100,000)
# - UrbanPop numeric Percent urban population (%)
# - Rape numeric Rape arrests (per 100,000) (K)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
#pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv("USArrests.csv", index_col=0)

# Her 100.000 tutuklamada suç türüne göre suç oranları olan bir data
# Bu değerleri 1000 ile çarpmamız gerekiyor
# index_col=0 : Bunu vermediğiniz zaman Eyaletleri 0. sütuna atıyor. Bunu verince eyaletleri indexe atmış olduk

# %%
df.head()
# UrbanPop: Eyaletlerin merkez nüfusunun tüm eyalete oranı
# Murder, Assault, Rape : Suç tipleri
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Alabama to Wyoming
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Murder    50 non-null     float64
#  1   Assault   50 non-null     int64
#  2   UrbanPop  50 non-null     int64
#  3   Rape      50 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 2.0+ KB

# %%
df.describe().T
# Out:
#           count     mean        std   min      25%     50%      75%    max
# Murder     50.0    7.788   4.355510   0.8    4.075    7.25   11.250   17.4
# Assault    50.0  170.760  83.337661  45.0  109.000  159.00  249.000  337.0
# UrbanPop   50.0   65.540  14.474763  32.0   54.500   66.00   77.750   91.0
# Rape       50.0   21.232   9.366385   7.3   15.075   20.10   26.175   46.0

# %%
sns.pairplot(df);
# Kümelemeyi rahat yapacağımız bir durum yok gibi ama iç içe girmeler olduğu için 2 diyebiliriz belki

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
murder = df.Murder.sort_values()
plt.figure(figsize = (14,6))
sns.barplot(y = murder, x = murder.index)
plt.xticks(rotation = 90);
# Cinayetin işlendiği eyaletlere göre oranlar

# %%
assault = df.Assault.sort_values()

plt.figure(figsize = (14,6))
sns.barplot(y = assault, x = assault.index)
plt.xticks(rotation = 90);
# Fiziksel saldırıların eyaletlere göre oranları

# %%
rape = df.Rape.sort_values()

plt.figure(figsize = (14,6))
sns.barplot(y = rape, x = rape.index)
plt.xticks(rotation = 90);
# Tecavüz suçunun eyaletlere göre oranları

# %% [markdown]
# ###### az suçun işlendiği, orta suçun işlendiği ve çok şuçun işlendiği eyaletler şeklinde ayırabiliriz ![image.png](attachment:image.png)

# %% [markdown]
# ## Hopkins Test

# %% [markdown]
# - Hopkins test, a statistical test for randomness of a variable.
# - Null Hypothesis (Ho) : Data points are generated by non-random, uniform distribution (implying no meaningful clusters)
# - Alternate Hypothesis (Ha): Data points are generated by random data points (presence of clusters)
# - The more close 0, the more available to separate clusters

# %%
#!pip install pyclustertend

# %%
from pyclustertend import hopkins

# %%
hopkins(df, df.shape[0]) # 0-0.5 arasında değerimiz. Kümelemeye yatkın olduğunu söyleyebiliriz
# Out:
# 0.43980159689600107

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# 2 farklı scale kullanarak hopkins test sonuçlarına bakalım

# %%
df1 = df.copy()
df2 = df.copy()

# %%
hopkins(MinMaxScaler().fit_transform(df1), df1.shape[0])
# Bu değer daha düşük o yüzden Minmaxscale ile devam edeceğiz
# DIKKAT: HOCA da çıktılar farklı burada skor 0.36 , alttaki 0.42
# Out:
# 0.3942295852154375

# %%
hopkins(StandardScaler().fit_transform(df2), df2.shape[0])
# Hocada bu 0.42
# Out:
# 0.36807847304267677

# %%
scaler = MinMaxScaler()

# %%
df_scaled = scaler.fit_transform(df)

# %%
X = pd.DataFrame(df_scaled, columns=df.columns)
X.head()
# Out:
#      Murder   Assault  UrbanPop      Rape
# 0  0.746988  0.654110  0.440678  0.359173
# 1  0.554217  0.746575  0.271186  0.961240
# 2  0.439759  0.852740  0.813559  0.612403
# 3  0.481928  0.496575  0.305085  0.315245
# 4  0.493976  0.791096  1.000000  0.860465

# %% [markdown]
# ## Dendrogram

# %% [markdown]
# - Tree-like hierarchical representation of clusters is called a dendrogram.
# - It illustrates the arrangement of the clusters produced by the corresponding analyses.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
#dendrogram()

# %% [markdown]
# **“linkage” parameter: (default= “ward”)**
#
#   {‘ward’, ‘complete’, ‘average’, ‘single’}
#
# Which linkage criterion to use. The linkage criterion determines which distance to use between sets of observation.
# -	Ward minimizes the variance of the clusters being merged.
# -	Average uses the average of the distances of each observation of the two sets.
# -	Complete or maximum linkage uses the maximum distances between all observations of the two sets.
# -	Single uses the minimum of the distances between all observations of the two sets.

# %%
hc_ward = linkage(y = X, method = "ward")
hc_complete = linkage(X, "complete")
hc_average = linkage(X, "average")
hc_single = linkage(X, "single")

# %%
plt.figure(figsize = (14,7))
dendrogram(hc_ward, leaf_font_size = 10);
# Dendogram a göre 2 sınıfa ayırabileceğimizi söylüyor(Mesela az suçun işlendiği ve çok şuçun işlendiği eyaletler)

# %%
plt.figure(figsize = (14,7))
dendrogram(hc_ward,
           truncate_mode = "lastp",
           p = 10,
           leaf_font_size = 10);

# %%
plt.figure(figsize = (20,12))

plt.subplot(221)
plt.title("Ward")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_ward, truncate_mode = "lastp", p = 10, leaf_font_size = 10)

plt.subplot(222)
plt.title("Complete")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_complete, truncate_mode = "lastp", p = 10, leaf_font_size = 10)

plt.subplot(223)
plt.title("Average")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_average, truncate_mode = "lastp", p = 10, leaf_font_size = 10)

plt.subplot(224)
plt.title("Single")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_single, truncate_mode = "lastp", p = 10, leaf_font_size = 10);

# Average farklı olarak 4 e ayırabilirsin demiş

# %% [markdown]
# ## Hierarchical Clustering (Agglomerative)

# %% [markdown]
# - Ideal clustering is characterised by minimal intra cluster distance and maximal inter cluster distanc

# %%
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### S(Silhouette) Score

# %% [markdown]
# - If the ground truth labels are not known, evaluation must be performed using the model itself. (One of the evaluation method is Silhouette Coefficient)
# - A higher Silhouette Coefficient score relates to a model with better defined clusters.
# - a :The mean distance between a sample and all other points in the same class.
#   b: The mean distance between a sample and all other points in the next nearest cluster.
#
# s = (b-a) / max(a,b)

# %%
from sklearn.metrics import silhouette_score

# %%
K = range(2,10)

for k in K:
    model = AgglomerativeClustering(n_clusters = k)
    model.fit_predict(X)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(df, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.5406742439027667
# Silhouette Score for 3 clusters: 0.35867841933636974
# Silhouette Score for 4 clusters: 0.19574129619567182
# Silhouette Score for 5 clusters: 0.08372985630683068
# Silhouette Score for 6 clusters: -0.0009786026955674342
# Silhouette Score for 7 clusters: -0.10043609614774641
# Silhouette Score for 8 clusters: -0.05885457794822918
# Silhouette Score for 9 clusters: -0.06385273624879925

# %%
# Silhouette Score 2 dedi ama mesela müşteri 3 cluster olsun dedi. Bu şekilde devam edelim
model = AgglomerativeClustering(n_clusters=3, affinity = "euclidean", linkage = "ward")
clusters = model.fit_predict(X)

# %%
X.head()
# Out:
#      Murder   Assault  UrbanPop      Rape
# 0  0.746988  0.654110  0.440678  0.359173
# 1  0.554217  0.746575  0.271186  0.961240
# 2  0.439759  0.852740  0.813559  0.612403
# 3  0.481928  0.496575  0.305085  0.315245
# 4  0.493976  0.791096  1.000000  0.860465

# %%
plt.figure(figsize = (20,18))
plot_number = 1
for i in X:
    for j in X:
        if j!=i:
            plt.subplot(4,3,plot_number)
            plt.scatter(X[j], X[i], c = clusters, cmap = "viridis")
            plt.xlabel(j)
            plt.ylabel(i)
            plot_number += 1
            
# 4 feature 3 class ımız var. Her bir kombinasyon için bir scatter plot çizdirdik
# Bütün featureların birbiri ile olan ilişkisini görüyoruz
# Hangi featureların nasıl ayrıştığını görüyoruz

# %% [markdown]
# ##### Solda ayrıştırma daha iyi ama ortadaki ve sağdakinde ayrıştırma çok iyi değil. Bu şekilde diğerlerine de bakabiliriz ama UrbanPop ın çok iyi bir feature olmadığını söyleyebiliriz
# ![image.png](attachment:image.png)

# %%
X["cluster"] = clusters
X.head()
# Out:
#      Murder   Assault  UrbanPop      Rape  cluster
# 0  0.746988  0.654110  0.440678  0.359173        0
# 1  0.554217  0.746575  0.271186  0.961240        0
# 2  0.439759  0.852740  0.813559  0.612403        0
# 3  0.481928  0.496575  0.305085  0.315245        1
# 4  0.493976  0.791096  1.000000  0.860465        0

# %%
clus_pred = X.groupby("cluster").mean().T  # Tahmin ettiğimiz değerler üzerinden(Öncekinde gerçek verileri kullanmıştık)
clus_pred
# Out:
# cluster          0         1         2
# Murder    0.684639  0.316600  0.138052
# Assault   0.720034  0.325533  0.106164
# UrbanPop  0.616949  0.666667  0.340395
# Rape      0.564987  0.294143  0.117140

# %%
sns.lineplot(data = clus_pred)
# Hangi feature lar belirleyici: Murder Assault ve Rape i seçebiliriz.
# Daha az feature olması için Murder ve Assault ı kullanabiliriz. Bundan sonrası tercih meselesi
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (20,6))

plt.subplot(141)
sns.boxplot(y = "Murder", x = "cluster", data = X)

plt.subplot(142)
sns.boxplot(y = "Assault", x = "cluster", data = X)

plt.subplot(143)
sns.boxplot(y = "Rape", x = "cluster", data = X)

plt.subplot(144)
sns.boxplot(y = "UrbanPop", x = "cluster", data = X);

# Murder ve assault ın daha ayrışrırıcı olduğunu söyleyebiliriz

# %%
X.cluster.value_counts() # Clusterlara göre gözlem sayıları
# Out:
# 0    20
# 1    18
# 2    12
# Name: cluster, dtype: int64

# %%
X2 = X.iloc[:, [0,1,3]]
X2.head()
# 3 feature ile modelleme yapalım, aynı adımları tekrar edelim
# Out:
#      Murder   Assault      Rape
# 0  0.746988  0.654110  0.359173
# 1  0.554217  0.746575  0.961240
# 2  0.439759  0.852740  0.612403
# 3  0.481928  0.496575  0.315245
# 4  0.493976  0.791096  0.860465

# %% [markdown]
# ## Hopkins test

# %%
hopkins(X2, X2.shape[0])
# 3 feature la hopkins test sonucu(Hocada bu sonuç 0.37, alttaki de 0.37)
# Out:
# 0.3378035759900971

# %% [raw]
# 0.3779127955224929

# %%
hc_ward = linkage(y = X2, method = "ward")
hc_complete = linkage(X2, "complete")
hc_average = linkage(X2, "average")
hc_single = linkage(X2, "single")

# %%
plt.figure(figsize = (20,12))

plt.subplot(221)
plt.title("Ward")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_ward, truncate_mode = "lastp", p = 10, leaf_font_size = 10)

plt.subplot(222)
plt.title("Complete")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_complete, truncate_mode = "lastp", p = 10, leaf_font_size = 10)

plt.subplot(223)
plt.title("Average")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_average, truncate_mode = "lastp", p = 10, leaf_font_size = 10)

plt.subplot(224)
plt.title("Single")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hc_single, truncate_mode = "lastp", p = 10, leaf_font_size = 10);

# Ward, Complete , Average 2 cluster ı tavsiye ediyor
# Single da 10 tane cluster ı tavsiye etmiş
# Ares hoca: En tutarlısı "ward"(Cluster lar arasındaki mesafelere baktığımızda)

# %%
K = range(2,11)

for k in K:
    model = AgglomerativeClustering(n_clusters = k)
    model.fit_predict(X2)
    print(f'Silhouette Score for {k} clusters: {silhouette_score(df, model.labels_)}')
# Out:
# Silhouette Score for 2 clusters: 0.5406742439027667
# Silhouette Score for 3 clusters: 0.33193668766161594
# Silhouette Score for 4 clusters: 0.13774732005543386
# Silhouette Score for 5 clusters: 0.13269348844287665
# Silhouette Score for 6 clusters: 0.051863884277307114
# Silhouette Score for 7 clusters: -0.05791022756192905
# Silhouette Score for 8 clusters: -0.06533546010208166
# Silhouette Score for 9 clusters: -0.025411681669985392
# Silhouette Score for 10 clusters: 0.02417352208175959

# %% [raw]
# Silhouette Score for 2 clusters: 0.5406742439027667
# Silhouette Score for 3 clusters: 0.35867841933636974
# Silhouette Score for 4 clusters: 0.19574129619567182
# Silhouette Score for 5 clusters: 0.08372985630683068
# Silhouette Score for 6 clusters: -0.0009786026955674342
# Silhouette Score for 7 clusters: -0.10043609614774641
# Silhouette Score for 8 clusters: -0.05885457794822918
# Silhouette Score for 9 clusters: -0.06385273624879925

# %%
# 3 feature ile modelimizi kuralım
final_model = AgglomerativeClustering(n_clusters=3, affinity = "euclidean", linkage = "ward")
clusters = final_model.fit_predict(X2) # Tahmin edilen değerler
X2["cluster"] = clusters

# %%
X2.cluster.value_counts()
# Out:
# 0    20
# 1    17
# 2    13
# Name: cluster, dtype: int64

# %% [raw]
# 0    20
# 1    18
# 2    12

# %%
plt.figure(figsize = (20,6))

plt.subplot(131)
sns.boxplot(y = "Murder", x = "cluster", data = X2)

plt.subplot(132)
sns.boxplot(y = "Assault", x = "cluster", data = X2)

plt.subplot(133)
sns.boxplot(y = "Rape", x = "cluster", data = X2)

# class chat soru: Hocam map({0:"high", 1:"low",2:"medium"}) önemli değilse nasıl isabet etti anlayamadım
# Alttaki ekran görüntüsünde Ares hoca cevap verdi
# Out:
# <AxesSubplot:xlabel='cluster', ylabel='Rape'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Evaluation**
#
# - 0 : states with high crime rates
# - 1 : states with low crime rates
# - 2 : states with medium crime rates

# %%
X2["crime_level"] = X2["cluster"].map({0:"high", 1:"low",2:"medium"})
X2.head()
# Out:
#      Murder   Assault      Rape  cluster crime_level
# 0  0.746988  0.654110  0.359173        0        high
# 1  0.554217  0.746575  0.961240        0        high
# 2  0.439759  0.852740  0.612403        0        high
# 3  0.481928  0.496575  0.315245        2      medium
# 4  0.493976  0.791096  0.860465        0        high

# %%
df.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
X2["States"] = df.index
X2
# Out:
#       Murder   Assault      Rape  cluster crime_level          States
# 0   0.746988  0.654110  0.359173        0        high         Alabama
# 1   0.554217  0.746575  0.961240        0        high          Alaska
# 2   0.439759  0.852740  0.612403        0        high         Arizona
# 3   0.481928  0.496575  0.315245        2      medium        Arkansas
# 4   0.493976  0.791096  0.860465        0        high      California
# 5   0.427711  0.544521  0.811370        0        high        Colorado
# 6   0.150602  0.222603  0.098191        1         low     Connecticut
# 7   0.307229  0.660959  0.219638        2      medium        Delaware
# 8   0.879518  0.993151  0.635659        0        high         Florida
# 9   1.000000  0.568493  0.478036        0        high         Georgia
# 10  0.271084  0.003425  0.333333        1         low          Hawaii
# 11  0.108434  0.256849  0.178295        1         low           Idaho
# ...

# %%
X2[X2.crime_level=="low"]["States"]
# Out:
# 6       Connecticut
# 10           Hawaii
# 11            Idaho
# 14             Iowa
# 15           Kansas
# 18            Maine
# 20    Massachusetts
# 22        Minnesota
# 25          Montana
# 26         Nebraska
# 28    New Hampshire
# 33     North Dakota
# 37     Pennsylvania
# 40     South Dakota
# 44          Vermont
# 47    West Virginia
# 48        Wisconsin
# Name: States, dtype: object

# %%
X2[X2.crime_level=="high"]["States"]
# Out:
# 0            Alabama
# 1             Alaska
# 2            Arizona
# 4         California
# 5           Colorado
# 8            Florida
# 9            Georgia
# 12          Illinois
# 17         Louisiana
# 19          Maryland
# 21          Michigan
# 23       Mississippi
# 24          Missouri
# 27            Nevada
# 30        New Mexico
# 31          New York
# 32    North Carolina
# 39    South Carolina
# 41         Tennessee
# 42             Texas
# Name: States, dtype: object

# %%
X2[X2.crime_level=="medium"]["States"]
# Out:
# 3         Arkansas
# 7         Delaware
# 13         Indiana
# 16        Kentucky
# 29      New Jersey
# 34            Ohio
# 35        Oklahoma
# 36          Oregon
# 38    Rhode Island
# 43            Utah
# 45        Virginia
# 46      Washington
# 49         Wyoming
# Name: States, dtype: object

# %%
# Dendogram ın dediği 2 clustering di müşterinin dediğine göre 3 yaptık
# Yeni bir gözlem getirdiğinde müşteri gelen datayı son satıra ekleyip tekrar modelleme yapmak gerekiyor
# En sonda da o gözlemin hangi eyalette olduğunu söyleyebilirsiniz müşteriye

# class chat soru: Hocam bütün featureların alındığı örnekte; dendrogram sonucunda average 4 cluster
# .. önerirken, silhouette_score 2 cluster öneriyor. Benzer şekilde K-means'te elbow method ile yine 
# .. silhouette_score farklı sonuçlar öenerebiliyordu. Bunun sonucunda (domain bilgisi ve müşteri 
# .. isteği olmadığı durumda) nasıl devam etmemiz gerektiği kısmı, mantığı oturmadı bende.
# .. Nasıl bir yol izlemeliyiz?

# Ares Hoca: Burada domain bilgisi önemli. Biz buralarda insightlar elde ediyoruz ama müşterinin istedğini gözardı edemeyiz
# .. Unsupervised learning bir nevir analiz gibi gruplama yapıyoruz supervised learning gibi değil
# Orion Hoca: clustering infreantial bir analizdir esasıda. Bir nevi EDA yaptıurıyorsunuz modele sizin yerinize
# Orion Hoca: clusterlar bulunduktan sonra cluster profiling yapmanız lazım. yani clusterları adlandırıp anlamlandırmazsanız clusteringin bir anlamı olmaz
